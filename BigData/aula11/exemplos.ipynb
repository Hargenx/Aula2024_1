# %% [markdown]
# ### Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Dataset

# %%
# %pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 10.6/10.6 MB 16.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 301.8/301.8 kB 9.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import load_iris
data = load_iris()
iris = pd.DataFrame(data.data, columns=data.feature_names)
target = data.target

# %% [markdown]
# ### instanciação simples do classificador

# %%
#Importando o algoritimo de SVM
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
#svc = SVC(kernel='linear', C=1)
svc = SVC(gamma='auto')

# %% [markdown]
# ### A validação cruzada

# %%
# Testando Modelo 'svc' na nossa base 'iris'
cv_result = cross_val_score(svc, iris, target, cv=10, scoring='accuracy')
print(f"Acurácia com cross validation: {cv_result.mean()*100}")
# Out:
# Acurácia com cross validation: 98.00000000000001

# %% [markdown]
# ### Dados e os hiperplanos definidos pelo modelo

# %%
plt.scatter(iris['sepal length (cm)'], iris['petal width (cm)'], c=target)
#plt.xlabel('sepal length (cm)')
#plt.ylabel('sepal width (cm)')
plt.title('Iris Dataset')
plt.show()
